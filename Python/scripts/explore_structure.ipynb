# %%
# Import the different packages

import os
import pandas as pd 
import numpy as np
from scipy.io import loadmat

# %%
# Write path and file

path_header = "../../osf_files/lsl_physio_data/"
file  = "ID_001_lsl_data.mat"

path = os.path.join(path_header, file)

data = loadmat(path, squeeze_me = True, struct_as_record = False)

# %%
# On boucle sur la liste lsl_data pour identifier qui est qui

labels = [c.info.name for c in data['lsl_data']]
print(labels)
# Out:
# ['pupil_capture', 'BrainVision RDA', 'fear_stream']

# %%
# On interroge les métadonnées pour avoir les noms des canaux dans l'ordre

labels = [c.label for c in data['lsl_data'][1].info.desc.channels.channel]
print(labels)

types = [c.type for c in data['lsl_data'][1].info.desc.channels.channel]
print(types)

units = [c.unit for c in data['lsl_data'][1].info.desc.channels.channel]
print(units)

# L'ordre n'est pas le bon dans le papier. Attention.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # On interroge les métadonnées pour avoir les noms des canaux dans l'ordre
# ----> 3 labels = [c.label for c in data['lsl_data'][1].info.desc.channels.channel]
#       4 print(labels)
#       6 types = [c.type for c in data['lsl_data'][1].info.desc.channels.channel]
#
# NameError: name 'data' is not defined

# %%
for i in range(3):
    obj = data['lsl_data'][i]
    print(f"Structure {i} ({obj.info.name}):")
    
    # On essaie le chemin A (yeux), sinon le chemin B (cœur), sinon on affiche l'erreur
    try:
        # Cas de l'eye-tracker 
        labels = [c.label for c in obj.info.desc.channels.channel]
    except AttributeError:
        try:
            # Cas fréquent de BrainVision 
            labels = [c.label for c in obj.info.desc.channel]
        except AttributeError:
            labels = "Pas de labels de canaux (flux d'événements)"
            
    print(f"  Labels trouvés : {labels}")
# Out:
# Structure 0 (pupil_capture):
#   Labels trouvés : ['confidence', 'norm_pos_x', 'norm_pos_y', 'gaze_point_3d_x', 'gaze_point_3d_y', 'gaze_point_3d_z', 'eye_center0_3d_x', 'eye_center0_3d_y', 'eye_center0_3d_z', 'eye_center1_3d_x', 'eye_center1_3d_y', 'eye_center1_3d_z', 'gaze_normal0_x', 'gaze_normal0_y', 'gaze_normal0_z', 'gaze_normal1_x', 'gaze_normal1_y', 'gaze_normal1_z', 'diameter0_2d', 'diameter1_2d', 'diameter0_3d', 'diameter1_3d']
# Structure 1 (BrainVision RDA):
#   Labels trouvés : ['ECG', 'Pulse', 'Resp', 'GSR_MR_100_xx']
# Structure 2 (fear_stream):
#   Labels trouvés : Pas de labels de canaux (flux d'événements)

# %%
from scipy.io import loadmat
import numpy as np

# On charge l'objet avec les arguments squeeze_me et struct_as_record, que je ne comprends pas très bien honnêtement. Ils semblent faciliter la navigation de l'objet.
data = loadmat(path, squeeze_me=True, struct_as_record=False) 
# Cette fonction va permettre de déplier l'objet et pouvoir inspecter sa structure.
def deep_inspect(obj, name="root", indent=0): # Je ne comprends pas bien les arguments, à l'exception du premier. 
    spacing = "  " * indent # Je ne comprends pas cette ligne. Ah, je pense que ça sert à décaller l'output en fonction du "niveau" et rendre la lecture de l'output lisible.
    if hasattr(obj, '__dict__'): # Si l'objet à l'attribut "__dict__" ; j'imagine que l'on vérifie simplement quel type d'attribus les différentes arborescence du dictionnaire présente.
        print(f"{spacing}Object: {name} (Matlab Struct)") # Je ne suis pas sûr de comment est réassigné "name", est-ce que ce sera "root" à chaque fois ?
        for field in vars(obj): # On va itérer sur tous les éléments de l'objet (pourquoi la fonction vars() est utilisée ?)
            if not field.startswith('_'): # Si le champs ne commence pas par '_', on applique la fonction qu'on est en train de rédiger ?! Comment est-ce que ça peut fonctionner ?
                deep_inspect(getattr(obj, field), field, indent + 1) # On récupère l'attribut de l'objet dans le champs correspond à l'itération.
    elif isinstance(obj, dict): # Si l'objet est de type dictionnaire.
        print(f"{spacing}Dict: {name}") # On affiche le nom de l'objet.
        for key in obj: # On va aussi itérer sur les différentes clefs du dictionnaire.
            if not key.startswith('__'): # Si ça ne commence pas par "__"
                deep_inspect(obj[key], key, indent + 1) # Encore une fois, on utilise la fonction elle-même, ce que je trouve super étrange.
    elif isinstance(obj, (list, np.ndarray)) and obj.dtype == object: # Si l'objet est une liste ou une matrice numpy ET obj.dtype == object (je ne comprends pas cette partie de la condition)
        print(f"{spacing}Array of Objects: {name} (Length: {len(obj)})") # On récupère les dimensions ici ?
        for i, item in enumerate(obj): # Quelle est la mécanique derrière "i, item" ? Comment itérer sur deux éléments ?
            deep_inspect(item, f"{name}[{i}]", indent + 1) # On réutilise la fonction elle-même en son sein. Je vais vraiment avoir besoin d'explications.
    else: # Dernière condition.
        detail = f" - Shape: {obj.shape}" if hasattr(obj, 'shape') else f" = {obj}" # Pourquoi la condition est APRÈS "f" - Shape: {obj.shape}""
        print(f"{spacing}Data: {name}{detail}") # On affiche le résultat.

deep_inspect(data['lsl_data'])
# Out:
# Array of Objects: root (Length: 3)
#   Object: root[0] (Matlab Struct)
#     Object: info (Matlab Struct)
#       Data: name = pupil_capture
#       Data: type = Gaze
#       Data: channel_count = 22
#       Data: nominal_srate = 0
#       Data: channel_format = double64
#       Data: source_id = 968dd986-d1d9-4ae0-abdb-969ac9b62c0c
#       Data: version = 1.1000000000000001
#       Data: created_at = 2873.9302124000001
#       Data: uid = aae3a43e-95c2-405a-bb9a-6d599b8bb0cf
#       Data: session_id = default
#       Data: hostname = a471-u052
#       Object: v4address (Matlab Struct)
#       Data: v4data_port = 16572
#       Data: v4service_port = 16572
#       Object: v6address (Matlab Struct)
#       Data: v6data_port = 16572
#       Data: v6service_port = 16572
#       Object: desc (Matlab Struct)
#         Object: channels (Matlab Struct)
#           Array of Objects: channel (Length: 22)
#             Object: channel[0] (Matlab Struct)
#               Data: label = confidence
#               Data: eye = both
#               Data: type = Confidence
#               Data: unit = normalized
#             Object: channel[1] (Matlab Struct)
#               Data: label = norm_pos_x
#               Data: eye = both
#               Data: type = ScreenX
#               Data: unit = normalized
#               Data: coordinate_system = world
#             Object: channel[2] (Matlab Struct)
#               Data: label = norm_pos_y
#               Data: eye = both
#               Data: type = ScreenY
#               Data: unit = normalized
#               Data: coordinate_system = world
#             Object: channel[3] (Matlab Struct)
#               Data: label = gaze_point_3d_x
#               Data: eye = both
#               Data: type = DirectionX
#               Data: unit = mm
#               Data: coordinate_system = world
#             Object: channel[4] (Matlab Struct)
#               Data: label = gaze_point_3d_y
#               Data: eye = both
#               Data: type = DirectionY
#               Data: unit = mm
#               Data: coordinate_system = world
#             Object: channel[5] (Matlab Struct)
#               Data: label = gaze_point_3d_z
#               Data: eye = both
#               Data: type = DirectionZ
#               Data: unit = mm
#               Data: coordinate_system = world
#             Object: channel[6] (Matlab Struct)
#               Data: label = eye_center0_3d_x
#               Data: eye = right
#               Data: type = PositionX
#               Data: unit = mm
#               Data: coordinate_system = world
#             Object: channel[7] (Matlab Struct)
#               Data: label = eye_center0_3d_y
#               Data: eye = right
#               Data: type = PositionY
#               Data: unit = mm
#               Data: coordinate_system = world
#             Object: channel[8] (Matlab Struct)
#               Data: label = eye_center0_3d_z
#               Data: eye = right
#               Data: type = PositionZ
#               Data: unit = mm
#               Data: coordinate_system = world
#             Object: channel[9] (Matlab Struct)
#               Data: label = eye_center1_3d_x
#               Data: eye = left
#               Data: type = PositionX
#               Data: unit = mm
#               Data: coordinate_system = world
#             Object: channel[10] (Matlab Struct)
#               Data: label = eye_center1_3d_y
#               Data: eye = left
#               Data: type = PositionY
#               Data: unit = mm
#               Data: coordinate_system = world
#             Object: channel[11] (Matlab Struct)
#               Data: label = eye_center1_3d_z
#               Data: eye = left
#               Data: type = PositionZ
#               Data: unit = mm
#               Data: coordinate_system = world
#             Object: channel[12] (Matlab Struct)
#               Data: label = gaze_normal0_x
#               Data: eye = right
#               Data: type = PositionX
#               Data: unit = mm
#               Data: coordinate_system = world
#             Object: channel[13] (Matlab Struct)
#               Data: label = gaze_normal0_y
#               Data: eye = right
#               Data: type = PositionY
#               Data: unit = mm
#               Data: coordinate_system = world
#             Object: channel[14] (Matlab Struct)
#               Data: label = gaze_normal0_z
#               Data: eye = right
#               Data: type = PositionZ
#               Data: unit = mm
#               Data: coordinate_system = world
#             Object: channel[15] (Matlab Struct)
#               Data: label = gaze_normal1_x
#               Data: eye = left
#               Data: type = PositionX
#               Data: unit = mm
#               Data: coordinate_system = world
#             Object: channel[16] (Matlab Struct)
#               Data: label = gaze_normal1_y
#               Data: eye = left
#               Data: type = PositionY
#               Data: unit = mm
#               Data: coordinate_system = world
#             Object: channel[17] (Matlab Struct)
#               Data: label = gaze_normal1_z
#               Data: eye = left
#               Data: type = PositionZ
#               Data: unit = mm
#               Data: coordinate_system = world
#             Object: channel[18] (Matlab Struct)
#               Data: label = diameter0_2d
#               Data: eye = right
#               Data: type = Diameter
#               Data: unit = pixels
#               Data: coordinate_system = eye0
#             Object: channel[19] (Matlab Struct)
#               Data: label = diameter1_2d
#               Data: eye = left
#               Data: type = Diameter
#               Data: unit = pixels
#               Data: coordinate_system = eye1
#             Object: channel[20] (Matlab Struct)
#               Data: label = diameter0_3d
#               Data: eye = right
#               Data: type = Diameter
#               Data: unit = mm
#               Data: coordinate_system = eye0
#             Object: channel[21] (Matlab Struct)
#               Data: label = diameter1_3d
#               Data: eye = left
#               Data: type = Diameter
#               Data: unit = mm
#               Data: coordinate_system = eye1
#       Object: clock_offsets (Matlab Struct)
#         Array of Objects: offset (Length: 689)
#           Object: offset[0] (Matlab Struct)
#             Data: time = 4040.8122876
#             Data: value = 4.100000069229282e-006
#           Object: offset[1] (Matlab Struct)
#             Data: time = 4045.81325265
#             Data: value = 1.500000053056283e-007
#           Object: offset[2] (Matlab Struct)
#             Data: time = 4050.81325455
#             Data: value = 3.499999365885742e-007
#           Object: offset[3] (Matlab Struct)
#             Data: time = 4055.8142371
#             Data: value = 3.000000106112566e-006
#           Object: offset[4] (Matlab Struct)
#             Data: time = 4060.8142721
#             Data: value = -2.499999936844688e-006
#           Object: offset[5] (Matlab Struct)
#             Data: time = 4065.8152455
#             Data: value = 2.699999868127634e-006
#           Object: offset[6] (Matlab Struct)
#             Data: time = 4070.81624045
#             Data: value = 6.450000000768341e-006
#           Object: offset[7] (Matlab Struct)
#             Data: time = 4075.81626465
#             Data: value = -5.249999958323315e-006
#           Object: offset[8] (Matlab Struct)
#             Data: time = 4080.8172475
#             Data: value = -1.099999963116716e-006
#           Object: offset[9] (Matlab Struct)
#             Data: time = 4085.81724765
#             Data: value = -7.500000265281415e-007
#           Object: offset[10] (Matlab Struct)
#             Data: time = 4090.8172667
#             Data: value = -1.120000001719745e-005
#           Object: offset[11] (Matlab Struct)
#             Data: time = 4095.81824885
#             Data: value = -2.550000090195681e-006
#           Object: offset[12] (Matlab Struct)
#             Data: time = 4100.8192648
#             Data: value = -2.100000529026147e-006
#           Object: offset[13] (Matlab Struct)
#             Data: time = 4105.8192394
#             Data: value = 4.600000011123484e-006
#           Object: offset[14] (Matlab Struct)
#             Data: time = 4110.8202473
#             Data: value = -4.900000021734741e-006
#           Object: offset[15] (Matlab Struct)
#             Data: time = 4115.820252049999
#             Data: value = -5.049999344919343e-006
#           Object: offset[16] (Matlab Struct)
#             Data: time = 4120.821252849999
#             Data: value = -3.949999609176302e-006
#           Object: offset[17] (Matlab Struct)
#             Data: time = 4125.821252199999
#             Data: value = -8.69999985297909e-006
#           Object: offset[18] (Matlab Struct)
#             Data: time = 4130.8212439
#             Data: value = 1.500000053056283e-006
#           Object: offset[19] (Matlab Struct)
#             Data: time = 4135.821249449999
#             Data: value = -3.749999450519681e-006
#           Object: offset[20] (Matlab Struct)
#             Data: time = 4140.8212487
#             Data: value = -8.000001798791345e-007
#           Object: offset[21] (Matlab Struct)
#             Data: time = 4145.82125825
#             Data: value = -2.550000317569356e-006
#           Object: offset[22] (Matlab Struct)
#             Data: time = 4150.82225125
#             Data: value = 2.150000455003465e-006
#           Object: offset[23] (Matlab Struct)
#             Data: time = 4155.82325215
#             Data: value = -6.650000159424963e-006
#           Object: offset[24] (Matlab Struct)
#             Data: time = 4160.82325505
#             Data: value = 6.250000296859071e-006
#           Object: offset[25] (Matlab Struct)
#             Data: time = 4165.824253549999
#             Data: value = -1.650000285735587e-006
#           Object: offset[26] (Matlab Struct)
#             Data: time = 4170.82526145
#             Data: value = -7.950000053824624e-006
#           Object: offset[27] (Matlab Struct)
#             Data: time = 4175.8262698
#             Data: value = -6.399999620043673e-006
#           Object: offset[28] (Matlab Struct)
#             Data: time = 4180.826252950001
#             Data: value = -9.15000009626965e-006
#           Object: offset[29] (Matlab Struct)
#             Data: time = 4185.8272766
#             Data: value = -1.630000042496249e-005
#           Object: offset[30] (Matlab Struct)
#             Data: time = 4190.8282599
#             Data: value = -3.500000275380444e-006
#           Object: offset[31] (Matlab Struct)
#             Data: time = 4195.82829215
#             Data: value = -6.649999704677612e-006
#           Object: offset[32] (Matlab Struct)
#             Data: time = 4200.82924685
#             Data: value = -5.450000116979936e-006
#           Object: offset[33] (Matlab Struct)
#             Data: time = 4205.829251249999
#             Data: value = -1.750000137690222e-006
#           Object: offset[34] (Matlab Struct)
#             Data: time = 4210.82932215
#             Data: value = -3.250000190746505e-006
#           Object: offset[35] (Matlab Struct)
#             Data: time = 4215.8292618
#             Data: value = -7.199999799922807e-006
#           Object: offset[36] (Matlab Struct)
#             Data: time = 4220.83025675
#             Data: value = -6.249999387364369e-006
#           Object: offset[37] (Matlab Struct)
#             Data: time = 4225.830257799999
#             Data: value = -5.79999959882116e-006
#           Object: offset[38] (Matlab Struct)
#             Data: time = 4230.831240799999
#             Data: value = 2.100000529026147e-006
#           Object: offset[39] (Matlab Struct)
#             Data: time = 4235.83125115
#             Data: value = -3.850000211969018e-006
#           Object: offset[40] (Matlab Struct)
#             Data: time = 4240.83126415
#             Data: value = -2.150000000256114e-006
#           Object: offset[41] (Matlab Struct)
#             Data: time = 4245.832250250001
#             Data: value = 1.549999979033601e-006
#           Object: offset[42] (Matlab Struct)
#             Data: time = 4250.83224935
#             Data: value = 2.45000001086737e-006
#           Object: offset[43] (Matlab Struct)
#             Data: time = 4255.832250949999
#             Data: value = 1.150000116467709e-006
#           Object: offset[44] (Matlab Struct)
#             Data: time = 4260.83324665
#             Data: value = -3.050000032089884e-006
#           Object: offset[45] (Matlab Struct)
#             Data: time = 4265.833267550001
#             Data: value = -1.949999841599492e-006
#           Object: offset[46] (Matlab Struct)
#             Data: time = 4270.833256649999
#             Data: value = -7.449999884556746e-006
#           Object: offset[47] (Matlab Struct)
#             Data: time = 4275.834242749999
#             Data: value = 3.15000033879187e-006
#           Object: offset[48] (Matlab Struct)
#             Data: time = 4280.8342711
#             Data: value = -5.699999746866524e-006
#           Object: offset[49] (Matlab Struct)
#             Data: time = 4285.83524735
#             Data: value = 2.050000148301479e-006
#           Object: offset[50] (Matlab Struct)
#             Data: time = 4290.8362657
#             Data: value = -7.699999969190685e-006
#           Object: offset[51] (Matlab Struct)
#             Data: time = 4295.836275449999
#             Data: value = -5.349999355530599e-006
#           Object: offset[52] (Matlab Struct)
#             Data: time = 4300.837247050001
#             Data: value = 1.749999682942871e-006
#           Object: offset[53] (Matlab Struct)
#             Data: time = 4305.83823965
#             Data: value = 1.005000058285077e-005
#           Object: offset[54] (Matlab Struct)
#             Data: time = 4310.83827925
#             Data: value = -1.255000051969546e-005
#           Object: offset[55] (Matlab Struct)
#             Data: time = 4315.83925825
#             Data: value = -6.149999990157085e-006
#           Object: offset[56] (Matlab Struct)
#             Data: time = 4320.83925865
#             Data: value = -1.949999841599492e-006
#           Object: offset[57] (Matlab Struct)
#             Data: time = 4325.839254550001
#             Data: value = -7.050000476738205e-006
#           Object: offset[58] (Matlab Struct)
#             Data: time = 4330.840253
#             Data: value = -8.499999694322469e-006
#           Object: offset[59] (Matlab Struct)
#             Data: time = 4335.8402608
#             Data: value = -7.399999958579429e-006
#           Object: offset[60] (Matlab Struct)
#             Data: time = 4340.84026405
#             Data: value = 3.499999365885742e-007
#           Object: offset[61] (Matlab Struct)
#             Data: time = 4345.841249499999
#             Data: value = -5.699999746866524e-006
#           Object: offset[62] (Matlab Struct)
#             Data: time = 4350.84125195
#             Data: value = -2.249999397463398e-006
#           Object: offset[63] (Matlab Struct)
#             Data: time = 4355.84225455
#             Data: value = -8.149999757733895e-006
#           Object: offset[64] (Matlab Struct)
#             Data: time = 4360.8432579
#             Data: value = -3.399999968678458e-006
#           Object: offset[65] (Matlab Struct)
#             Data: time = 4365.8442529
#             Data: value = -2.999999651365215e-006
#           Object: offset[66] (Matlab Struct)
#             Data: time = 4370.845257100001
#             Data: value = -6.900000698806252e-006
#           Object: offset[67] (Matlab Struct)
#             Data: time = 4375.84525665
#             Data: value = -5.34999981027795e-006
#           Object: offset[68] (Matlab Struct)
#             Data: time = 4380.847257650001
#             Data: value = -6.650000159424963e-006
#           Object: offset[69] (Matlab Struct)
#             Data: time = 4385.847261250001
#             Data: value = -1.849999989644857e-006
#           Object: offset[70] (Matlab Struct)
#             Data: time = 4390.8472583
#             Data: value = -6.400000074791024e-006
#           Object: offset[71] (Matlab Struct)
#             Data: time = 4395.848262600001
#             Data: value = -4.799999715032755e-006
#           Object: offset[72] (Matlab Struct)
#             Data: time = 4400.84927475
#             Data: value = -6.450000000768341e-006
#           Object: offset[73] (Matlab Struct)
#             Data: time = 4405.8502626
#             Data: value = -6.100000064179767e-006
#           Object: offset[74] (Matlab Struct)
#             Data: time = 4410.85126175
#             Data: value = -7.15000032869284e-006
#           Object: offset[75] (Matlab Struct)
#             Data: time = 4415.852267750001
#             Data: value = -6.149999990157085e-006
#           Object: offset[76] (Matlab Struct)
#             Data: time = 4420.85325425
#             Data: value = -6.050000138202449e-006
#           Object: offset[77] (Matlab Struct)
#             Data: time = 4425.85325885
#             Data: value = -5.549999968934571e-006
#           Object: offset[78] (Matlab Struct)
#             Data: time = 4430.8542673
#             Data: value = -7.300000106624793e-006
#           Object: offset[79] (Matlab Struct)
#             Data: time = 4435.854262749999
#             Data: value = -1.105000001189183e-005
#           Object: offset[80] (Matlab Struct)
#             Data: time = 4440.854278050001
#             Data: value = -7.250000180647476e-006
#           Object: offset[81] (Matlab Struct)
#             Data: time = 4445.85426435
#             Data: value = -7.15000032869284e-006
#           Object: offset[82] (Matlab Struct)
#             Data: time = 4450.855276800001
#             Data: value = -8.900000011635711e-006
#           Object: offset[83] (Matlab Struct)
#             Data: time = 4455.8562833
#             Data: value = -4.300000000512227e-006
#           Object: offset[84] (Matlab Struct)
#             Data: time = 4460.85725675
#             Data: value = -5.949999831500463e-006
#           Object: offset[85] (Matlab Struct)
#             Data: time = 4465.85726395
#             Data: value = -4.150000222580275e-006
#           Object: offset[86] (Matlab Struct)
#             Data: time = 4470.8583061
#             Data: value = -4.499999704421498e-006
#           Object: offset[87] (Matlab Struct)
#             Data: time = 4475.859261600001
#             Data: value = -4.600000011123484e-006
#           Object: offset[88] (Matlab Struct)
#             Data: time = 4480.85929375
#             Data: value = -4.050000370625639e-006
#           Object: offset[89] (Matlab Struct)
#             Data: time = 4485.86025365
#             Data: value = -5.749999672843842e-006
#           Object: offset[90] (Matlab Struct)
#             Data: time = 4490.86125365
#             Data: value = -6.650000159424963e-006
#           Object: offset[91] (Matlab Struct)
#             Data: time = 4495.8612679
#             Data: value = -6.70000008540228e-006
#           Object: offset[92] (Matlab Struct)
#             Data: time = 4500.861265099999
#             Data: value = -6.299999768089037e-006
#           Object: offset[93] (Matlab Struct)
#             Data: time = 4505.863265599999
#             Data: value = -7.699999514443334e-006
#           Object: offset[94] (Matlab Struct)
#             Data: time = 4510.863278049999
#             Data: value = -8.550000075047137e-006
#           Object: offset[95] (Matlab Struct)
#             Data: time = 4515.86325375
#             Data: value = -2.2500003069581e-006
#           Object: offset[96] (Matlab Struct)
#             Data: time = 4520.86427385
#             Data: value = 2.150000000256114e-006
#           Object: offset[97] (Matlab Struct)
#             Data: time = 4525.865268
#             Data: value = -4.099999841855606e-006
#           Object: offset[98] (Matlab Struct)
#             Data: time = 4530.86626265
#             Data: value = -9.350000254926272e-006
#           Object: offset[99] (Matlab Struct)
#             Data: time = 4535.86726565
#             Data: value = -7.350000032602111e-006
#           Object: offset[100] (Matlab Struct)
#             Data: time = 4540.86725985
#             Data: value = -7.950000053824624e-006
#           Object: offset[101] (Matlab Struct)
#             Data: time = 4545.8672673
#             Data: value = -8.799999704933725e-006
#           Object: offset[102] (Matlab Struct)
#             Data: time = 4550.86827875
#             Data: value = -6.149999990157085e-006
#           Object: offset[103] (Matlab Struct)
#             Data: time = 4555.869250250001
#             Data: value = -3.050000486837234e-006
#           Object: offset[104] (Matlab Struct)
#             Data: time = 4560.869347850001
#             Data: value = -9.250000402971637e-006
#           Object: offset[105] (Matlab Struct)
#             Data: time = 4565.8692515
#             Data: value = -4.500000159168849e-006
#           Object: offset[106] (Matlab Struct)
#             Data: time = 4570.87026415
#             Data: value = -6.049999683455098e-006
#           Object: offset[107] (Matlab Struct)
#             Data: time = 4575.870265600001
#             Data: value = -5.899999905523146e-006
#           Object: offset[108] (Matlab Struct)
#             Data: time = 4580.87026565
#             Data: value = -6.350000148813706e-006
#           Object: offset[109] (Matlab Struct)
#             Data: time = 4585.87125805
#             Data: value = -8.749999778956408e-006
#           Object: offset[110] (Matlab Struct)
#             Data: time = 4590.8712553
#             Data: value = -4.499999704421498e-006
#           Object: offset[111] (Matlab Struct)
#             Data: time = 4595.8722694
#             Data: value = -5.500000042957254e-006
#           Object: offset[112] (Matlab Struct)
#             Data: time = 4600.8722638
#             Data: value = -6.899999789311551e-006
#           Object: offset[113] (Matlab Struct)
#             Data: time = 4605.8723637
#             Data: value = -7.000000096013537e-006
#           Object: offset[114] (Matlab Struct)
#             Data: time = 4610.87325395
#             Data: value = -1.499997779319529e-007
#           Object: offset[115] (Matlab Struct)
#             Data: time = 4615.87429345
#             Data: value = -7.749999895168003e-006
#           Object: offset[116] (Matlab Struct)
#             Data: time = 4620.87428
#             Data: value = -3.899999683198985e-006
#           Object: offset[117] (Matlab Struct)
#             Data: time = 4625.8752545
#             Data: value = -7.399999958579429e-006
#           Object: offset[118] (Matlab Struct)
#             Data: time = 4630.875258
#             Data: value = -7.200000254670158e-006
#           Object: offset[119] (Matlab Struct)
#             Data: time = 4635.8752694
#             Data: value = -6.799999937356915e-006
#           Object: offset[120] (Matlab Struct)
#             Data: time = 4640.87626105
#             Data: value = -3.050000032089884e-006
#           Object: offset[121] (Matlab Struct)
#             Data: time = 4645.876281300001
#             Data: value = -9.300000328948954e-006
#           Object: offset[122] (Matlab Struct)
#             Data: time = 4650.8762622
#             Data: value = -8.199999683711212e-006
#           Object: offset[123] (Matlab Struct)
#             Data: time = 4655.87626275
#             Data: value = -7.449999884556746e-006
#           Object: offset[124] (Matlab Struct)
#             Data: time = 4660.8772525
#             Data: value = -6.70000008540228e-006
#           Object: offset[125] (Matlab Struct)
#             Data: time = 4665.877267849999
#             Data: value = -9.249999948224286e-006
#           Object: offset[126] (Matlab Struct)
#             Data: time = 4670.878264949999
#             Data: value = -5.649999820889207e-006
#           Object: offset[127] (Matlab Struct)
#             Data: time = 4675.878259749999
#             Data: value = -7.249999725900125e-006
#           Object: offset[128] (Matlab Struct)
#             Data: time = 4680.8792755
#             Data: value = -6.70000008540228e-006
#           Object: offset[129] (Matlab Struct)
#             Data: time = 4685.88025625
#             Data: value = -7.249999725900125e-006
#           Object: offset[130] (Matlab Struct)
#             Data: time = 4690.8802665
#             Data: value = -8.50000014906982e-006
#           Object: offset[131] (Matlab Struct)
#             Data: time = 4695.88125355
#             Data: value = -8.349999461643165e-006
#           Object: offset[132] (Matlab Struct)
#             Data: time = 4700.8822384
#             Data: value = 1.400000201101648e-006
#           Object: offset[133] (Matlab Struct)
#             Data: time = 4705.8832634
#             Data: value = -4.999999873689376e-006
#           Object: offset[134] (Matlab Struct)
#             Data: time = 4710.8842852
#             Data: value = -7.199999799922807e-006
#           Object: offset[135] (Matlab Struct)
#             Data: time = 4715.88526245
#             Data: value = -7.250000180647476e-006
#           Object: offset[136] (Matlab Struct)
#             Data: time = 4720.886249499999
#             Data: value = -4.600000011123484e-006
#           Object: offset[137] (Matlab Struct)
#             Data: time = 4725.8872566
#             Data: value = -4.499999704421498e-006
#           Object: offset[138] (Matlab Struct)
#             Data: time = 4730.8872557
#             Data: value = -5.399999736255268e-006
#           Object: offset[139] (Matlab Struct)
#             Data: time = 4735.88728485
#             Data: value = -1.15500001811597e-005
#           Object: offset[140] (Matlab Struct)
#             Data: time = 4740.88827705
#             Data: value = -4.949999947712058e-006
#           Object: offset[141] (Matlab Struct)
#             Data: time = 4745.8892505
#             Data: value = -3.600000127335079e-006
#           Object: offset[142] (Matlab Struct)
#             Data: time = 4750.8892829
#             Data: value = -5.999999757477781e-006
#           Object: offset[143] (Matlab Struct)
#             Data: time = 4755.88925895
#             Data: value = -6.250000296859071e-006
#           Object: offset[144] (Matlab Struct)
#             Data: time = 4760.88927145
#             Data: value = 2.849999873433262e-006
#           Object: offset[145] (Matlab Struct)
#             Data: time = 4765.8902533
#             Data: value = -2.700000095501309e-006
#           Object: offset[146] (Matlab Struct)
#             Data: time = 4770.8902573
#             Data: value = -3.700000434037065e-006
#           Object: offset[147] (Matlab Struct)
#             Data: time = 4775.89125105
#             Data: value = -5.950000286247814e-006
#           Object: offset[148] (Matlab Struct)
#             Data: time = 4780.89126025
#             Data: value = -6.049999683455098e-006
#           Object: offset[149] (Matlab Struct)
#             Data: time = 4785.891275200001
#             Data: value = -8.50000014906982e-006
#           Object: offset[150] (Matlab Struct)
#             Data: time = 4790.892248
#             Data: value = -1.699999756965553e-006
#           Object: offset[151] (Matlab Struct)
#             Data: time = 4795.8922656
#             Data: value = -1.109999993786914e-005
#           Object: offset[152] (Matlab Struct)
#             Data: time = 4800.89325825
#             Data: value = -6.350000148813706e-006
#           Object: offset[153] (Matlab Struct)
#             Data: time = 4805.8942849
#             Data: value = -4.699999863078119e-006
#           Object: offset[154] (Matlab Struct)
#             Data: time = 4810.89426455
#             Data: value = -6.049999683455098e-006
#           Object: offset[155] (Matlab Struct)
#             Data: time = 4815.89426375
#             Data: value = -3.850000211969018e-006
#           Object: offset[156] (Matlab Struct)
#             Data: time = 4820.895253100001
#             Data: value = -7.900000582594657e-006
#           Object: offset[157] (Matlab Struct)
#             Data: time = 4825.8962554
#             Data: value = -6.199999916134402e-006
#           Object: offset[158] (Matlab Struct)
#             Data: time = 4830.8962547
#             Data: value = -1.399999746354297e-006
#           Object: offset[159] (Matlab Struct)
#             Data: time = 4835.89626695
#             Data: value = -8.149999757733895e-006
#           Object: offset[160] (Matlab Struct)
#             Data: time = 4840.897247800001
#             Data: value = -1.100000190490391e-006
#           Object: offset[161] (Matlab Struct)
#             Data: time = 4845.8972505
#             Data: value = -6.000000212225132e-006
#           Object: offset[162] (Matlab Struct)
#             Data: time = 4850.897247499999
#             Data: value = -3.499999820633093e-006
#           Object: offset[163] (Matlab Struct)
#             Data: time = 4855.89742925
#             Data: value = -4.550000085146166e-006
#           Object: offset[164] (Matlab Struct)
#             Data: time = 4860.8982674
#             Data: value = -3.600000127335079e-006
#           Object: offset[165] (Matlab Struct)
#             Data: time = 4865.9002471
#             Data: value = -4.300000455259578e-006
#           Object: offset[166] (Matlab Struct)
#             Data: time = 4870.90025065
#             Data: value = -2.350000158912735e-006
#           Object: offset[167] (Matlab Struct)
#             Data: time = 4875.901255549999
#             Data: value = -2.149999545508763e-006
#           Object: offset[168] (Matlab Struct)
#             Data: time = 4880.901253300001
#             Data: value = 3.999998625658918e-007
#           Object: offset[169] (Matlab Struct)
#             Data: time = 4885.901271000001
#             Data: value = -6.600000233447645e-006
#           Object: offset[170] (Matlab Struct)
#             Data: time = 4890.90225285
#             Data: value = -6.049999683455098e-006
#           Object: offset[171] (Matlab Struct)
#             Data: time = 4895.902261450001
#             Data: value = -8.95000039236038e-006
#           Object: offset[172] (Matlab Struct)
#             Data: time = 4900.9032639
#             Data: value = -4.500000159168849e-006
#           Object: offset[173] (Matlab Struct)
#             Data: time = 4905.9032796
#             Data: value = -9.000000318337698e-006
#           Object: offset[174] (Matlab Struct)
#             Data: time = 4910.904257550001
#             Data: value = -6.149999990157085e-006
#           Object: offset[175] (Matlab Struct)
#             Data: time = 4915.90526005
#             Data: value = -7.249999725900125e-006
#           Object: offset[176] (Matlab Struct)
#             Data: time = 4920.90626205
#             Data: value = -8.549999620299786e-006
#           Object: offset[177] (Matlab Struct)
#             Data: time = 4925.907251899999
#             Data: value = -2.099999619531445e-006
#           Object: offset[178] (Matlab Struct)
#             Data: time = 4930.90724715
#             Data: value = -4.250000529282261e-006
#           Object: offset[179] (Matlab Struct)
#             Data: time = 4935.9072575
#             Data: value = -5.300000339047983e-006
#           Object: offset[180] (Matlab Struct)
#             Data: time = 4940.90725035
#             Data: value = -3.250000190746505e-006
#           Object: offset[181] (Matlab Struct)
#             Data: time = 4945.90827305
#             Data: value = -9.450000106880907e-006
#           Object: offset[182] (Matlab Struct)
#             Data: time = 4950.9092618
#             Data: value = -7.500000265281415e-006
#           Object: offset[183] (Matlab Struct)
#             Data: time = 4955.91025135
#             Data: value = -8.049999905779259e-006
#           Object: offset[184] (Matlab Struct)
#             Data: time = 4960.9112609
#             Data: value = -6.799999937356915e-006
#           Object: offset[185] (Matlab Struct)
#             Data: time = 4965.9112563
#             Data: value = -4.600000011123484e-006
#           Object: offset[186] (Matlab Struct)
#             Data: time = 4970.9122501
#             Data: value = -3.000000106112566e-007
#           Object: offset[187] (Matlab Struct)
#             Data: time = 4975.91326745
#             Data: value = -9.450000106880907e-006
#           Object: offset[188] (Matlab Struct)
#             Data: time = 4980.91427105
#             Data: value = -5.949999831500463e-006
#           Object: offset[189] (Matlab Struct)
#             Data: time = 4985.91425215
#             Data: value = -6.950000170036219e-006
#           Object: offset[190] (Matlab Struct)
#             Data: time = 4990.914261150001
#             Data: value = -6.050000138202449e-006
#           Object: offset[191] (Matlab Struct)
#             Data: time = 4995.914300500001
#             Data: value = -9.500000032858225e-006
#           Object: offset[192] (Matlab Struct)
#             Data: time = 5000.915253849999
#             Data: value = -6.749999556632247e-006
#           Object: offset[193] (Matlab Struct)
#             Data: time = 5005.9162493
#             Data: value = -7.399999958579429e-006
#           Object: offset[194] (Matlab Struct)
#             Data: time = 5010.91625275
#             Data: value = -8.850000085658394e-006
#           Object: offset[195] (Matlab Struct)
#             Data: time = 5015.916255100001
#             Data: value = -2.799999947455945e-006
#           Object: offset[196] (Matlab Struct)
#             Data: time = 5020.9172534
#             Data: value = -4.399999852466863e-006
#           Object: offset[197] (Matlab Struct)
#             Data: time = 5025.91725555
#             Data: value = -6.450000000768341e-006
#           Object: offset[198] (Matlab Struct)
#             Data: time = 5030.91725205
#             Data: value = -5.749999672843842e-006
#           Object: offset[199] (Matlab Struct)
#             Data: time = 5035.917264950001
#             Data: value = -1.035000059346203e-005
#           Object: offset[200] (Matlab Struct)
#             Data: time = 5040.917255349999
#             Data: value = -6.849999863334233e-006
#           Object: offset[201] (Matlab Struct)
#             Data: time = 5045.918256500001
#             Data: value = -5.700000201613875e-006
#           Object: offset[202] (Matlab Struct)
#             Data: time = 5050.91927765
#             Data: value = -3.35000004270114e-006
#           Object: offset[203] (Matlab Struct)
#             Data: time = 5055.919254750001
#             Data: value = -5.750000582338544e-006
#           Object: offset[204] (Matlab Struct)
#             Data: time = 5060.919261200001
#             Data: value = -1.020000036078272e-005
#           Object: offset[205] (Matlab Struct)
#             Data: time = 5065.919290349999
#             Data: value = -6.349999694066355e-006
#           Object: offset[206] (Matlab Struct)
#             Data: time = 5070.9202657
#             Data: value = -1.23999998322688e-005
#           Object: offset[207] (Matlab Struct)
#             Data: time = 5075.92125365
#             Data: value = -7.050000021990854e-006
#           Object: offset[208] (Matlab Struct)
#             Data: time = 5080.92125155
#             Data: value = -2.450000465614721e-006
#           Object: offset[209] (Matlab Struct)
#             Data: time = 5085.9212596
#             Data: value = -1.80000006366754e-006
#           Object: offset[210] (Matlab Struct)
#             Data: time = 5090.92129015
#             Data: value = -5.950000286247814e-006
#           Object: offset[211] (Matlab Struct)
#             Data: time = 5095.92226745
#             Data: value = -9.449999652133556e-006
#           Object: offset[212] (Matlab Struct)
#             Data: time = 5100.922265550001
#             Data: value = -6.850000318081584e-006
#           Object: offset[213] (Matlab Struct)
#             Data: time = 5105.923251400001
#             Data: value = -4.000003173132427e-007
#           Object: offset[214] (Matlab Struct)
#             Data: time = 5110.92327095
#             Data: value = -7.749999895168003e-006
#           Object: offset[215] (Matlab Struct)
#             Data: time = 5115.92327965
#             Data: value = -6.950000170036219e-006
#           Object: offset[216] (Matlab Struct)
#             Data: time = 5120.924282649999
#             Data: value = -9.049999789567664e-006
#           Object: offset[217] (Matlab Struct)
#             Data: time = 5125.92526275
#             Data: value = -1.164999957836699e-005
#           Object: offset[218] (Matlab Struct)
#             Data: time = 5130.92626885
#             Data: value = -7.449999884556746e-006
#           Object: offset[219] (Matlab Struct)
#             Data: time = 5135.92725755
#             Data: value = 1.249999968422344e-006
#           Object: offset[220] (Matlab Struct)
#             Data: time = 5140.9272749
#             Data: value = -7.399999958579429e-006
#           Object: offset[221] (Matlab Struct)
#             Data: time = 5145.928275400001
#             Data: value = -9.100000170292333e-006
#           Object: offset[222] (Matlab Struct)
#             Data: time = 5150.92925405
#             Data: value = -7.050000021990854e-006
#           Object: offset[223] (Matlab Struct)
#             Data: time = 5155.92925705
#             Data: value = -5.950000286247814e-006
#           Object: offset[224] (Matlab Struct)
#             Data: time = 5160.92929265
#             Data: value = -8.449999768345151e-006
#           Object: offset[225] (Matlab Struct)
#             Data: time = 5165.929261200001
#             Data: value = -5.800000508315861e-006
#           Object: offset[226] (Matlab Struct)
#             Data: time = 5170.93026325
#             Data: value = -5.949999831500463e-006
#           Object: offset[227] (Matlab Struct)
#             Data: time = 5175.9312615
#             Data: value = -7.500000265281415e-006
#           Object: offset[228] (Matlab Struct)
#             Data: time = 5180.932257750001
#             Data: value = -8.049999905779259e-006
#           Object: offset[229] (Matlab Struct)
#             Data: time = 5185.933270250001
#             Data: value = -4.150000677327626e-006
#           Object: offset[230] (Matlab Struct)
#             Data: time = 5190.9342548
#             Data: value = -4.200000148557592e-006
#           Object: offset[231] (Matlab Struct)
#             Data: time = 5195.93426955
#             Data: value = -8.24999960968853e-006
#           Object: offset[232] (Matlab Struct)
#             Data: time = 5200.93525635
#             Data: value = -7.649999588466017e-006
#           Object: offset[233] (Matlab Struct)
#             Data: time = 5205.9352565
#             Data: value = -4.499999704421498e-006
#           Object: offset[234] (Matlab Struct)
#             Data: time = 5210.935264299999
#             Data: value = -1.999997039092705e-007
#           Object: offset[235] (Matlab Struct)
#             Data: time = 5215.936266700001
#             Data: value = -5.200000032345997e-006
#           Object: offset[236] (Matlab Struct)
#             Data: time = 5220.9362662
#             Data: value = -2.900000254157931e-006
#           Object: offset[237] (Matlab Struct)
#             Data: time = 5225.9372602
#             Data: value = -5.700000201613875e-006
#           Object: offset[238] (Matlab Struct)
#             Data: time = 5230.93726015
#             Data: value = -7.750000349915354e-006
#           Object: offset[239] (Matlab Struct)
#             Data: time = 5235.937269
#             Data: value = -7.999999979801942e-006
#           Object: offset[240] (Matlab Struct)
#             Data: time = 5240.93930265
#             Data: value = -8.749999778956408e-006
#           Object: offset[241] (Matlab Struct)
#             Data: time = 5245.939255400001
#             Data: value = -1.000000338535756e-006
#           Object: offset[242] (Matlab Struct)
#             Data: time = 5250.940260650001
#             Data: value = -6.850000318081584e-006
#           Object: offset[243] (Matlab Struct)
#             Data: time = 5255.94127135
#             Data: value = -7.050000021990854e-006
#           Object: offset[244] (Matlab Struct)
#             Data: time = 5260.9422622
#             Data: value = -5.400000191002619e-006
#           Object: offset[245] (Matlab Struct)
#             Data: time = 5265.9422622
#             Data: value = -7.499999810534064e-006
#           Object: offset[246] (Matlab Struct)
#             Data: time = 5270.943261550001
#             Data: value = -4.650000391848153e-006
#           Object: offset[247] (Matlab Struct)
#             Data: time = 5275.94325165
#             Data: value = -2.150000000256114e-006
#           Object: offset[248] (Matlab Struct)
#             Data: time = 5280.94327035
#             Data: value = -6.549999852722976e-006
#           Object: offset[249] (Matlab Struct)
#             Data: time = 5285.94425415
#             Data: value = -4.649999937100802e-006
#           Object: offset[250] (Matlab Struct)
#             Data: time = 5290.94426205
#             Data: value = -4.749999789055437e-006
#           Object: offset[251] (Matlab Struct)
#             Data: time = 5295.9452649
#             Data: value = -6.999999641266186e-006
#           Object: offset[252] (Matlab Struct)
#             Data: time = 5300.94626155
#             Data: value = -5.949999831500463e-006
#           Object: offset[253] (Matlab Struct)
#             Data: time = 5305.9462673
#             Data: value = -4.699999863078119e-006
#           Object: offset[254] (Matlab Struct)
#             Data: time = 5310.94626675
#             Data: value = -7.650000043213368e-006
#           Object: offset[255] (Matlab Struct)
#             Data: time = 5315.9472544
#             Data: value = -4.300000455259578e-006
#           Object: offset[256] (Matlab Struct)
#             Data: time = 5320.9472652
#             Data: value = -6.199999916134402e-006
#           Object: offset[257] (Matlab Struct)
#             Data: time = 5325.947261449999
#             Data: value = -5.049999799666693e-006
#           Object: offset[258] (Matlab Struct)
#             Data: time = 5330.948261
#             Data: value = -5.899999905523146e-006
#           Object: offset[259] (Matlab Struct)
#             Data: time = 5335.94826415
#             Data: value = -6.050000138202449e-006
#           Object: offset[260] (Matlab Struct)
#             Data: time = 5340.9482682
#             Data: value = -7.000000096013537e-006
#           Object: offset[261] (Matlab Struct)
#             Data: time = 5345.949256800001
#             Data: value = -4.200000148557592e-006
#           Object: offset[262] (Matlab Struct)
#             Data: time = 5350.9492841
#             Data: value = -5.699999746866524e-006
#           Object: offset[263] (Matlab Struct)
#             Data: time = 5355.949262249999
#             Data: value = -4.449999323696829e-006
#           Object: offset[264] (Matlab Struct)
#             Data: time = 5360.950257500001
#             Data: value = -7.100000402715523e-006
#           Object: offset[265] (Matlab Struct)
#             Data: time = 5365.9502731
#             Data: value = -9.200000022246968e-006
#           Object: offset[266] (Matlab Struct)
#             Data: time = 5370.95125625
#             Data: value = -5.649999820889207e-006
#           Object: offset[267] (Matlab Struct)
#             Data: time = 5375.95125545
#             Data: value = -2.45000001086737e-006
#           Object: offset[268] (Matlab Struct)
#             Data: time = 5380.95142865
#             Data: value = -4.750000243802788e-006
#           Object: offset[269] (Matlab Struct)
#             Data: time = 5385.95226305
#             Data: value = -2.349999704165384e-006
#           Object: offset[270] (Matlab Struct)
#             Data: time = 5390.95325875
#             Data: value = -7.649999588466017e-006
#           Object: offset[271] (Matlab Struct)
#             Data: time = 5395.953266
#             Data: value = -3.600000127335079e-006
#           Object: offset[272] (Matlab Struct)
#             Data: time = 5400.9542618
#             Data: value = -5.599999894911889e-006
#           Object: offset[273] (Matlab Struct)
#             Data: time = 5405.9552654
#             Data: value = -6.400000074791024e-006
#           Object: offset[274] (Matlab Struct)
#             Data: time = 5410.956263349999
#             Data: value = -4.549999630398816e-006
#           Object: offset[275] (Matlab Struct)
#             Data: time = 5415.95625825
#             Data: value = -2.850000328180613e-006
#           Object: offset[276] (Matlab Struct)
#             Data: time = 5420.95626515
#             Data: value = -9.650000265537528e-006
#           Object: offset[277] (Matlab Struct)
#             Data: time = 5425.957275550001
#             Data: value = -5.850000434293179e-006
#           Object: offset[278] (Matlab Struct)
#             Data: time = 5430.9582612
#             Data: value = -3.79999983124435e-006
#           Object: offset[279] (Matlab Struct)
#             Data: time = 5435.9592534
#             Data: value = -6.599999778700294e-006
#           Object: offset[280] (Matlab Struct)
#             Data: time = 5440.959254150001
#             Data: value = -3.249999735999154e-006
#           Object: offset[281] (Matlab Struct)
#             Data: time = 5445.96027765
#             Data: value = -4.750000243802788e-006
#           Object: offset[282] (Matlab Struct)
#             Data: time = 5450.960279749999
#             Data: value = -7.449999884556746e-006
#           Object: offset[283] (Matlab Struct)
#             Data: time = 5455.9612574
#             Data: value = -7.999999979801942e-006
#           Object: offset[284] (Matlab Struct)
#             Data: time = 5460.961312899999
#             Data: value = -5.999999757477781e-006
#           Object: offset[285] (Matlab Struct)
#             Data: time = 5465.96225825
#             Data: value = -7.849999292375287e-006
#           Object: offset[286] (Matlab Struct)
#             Data: time = 5470.962335550001
#             Data: value = -5.650000275636558e-006
#           Object: offset[287] (Matlab Struct)
#             Data: time = 5475.96326065
#             Data: value = -5.050000254414044e-006
#           Object: offset[288] (Matlab Struct)
#             Data: time = 5480.96425565
#             Data: value = -6.450000000768341e-006
#           Object: offset[289] (Matlab Struct)
#             Data: time = 5485.96428035
#             Data: value = -7.650000043213368e-006
#           Object: offset[290] (Matlab Struct)
#             Data: time = 5490.9642618
#             Data: value = -8.69999985297909e-006
#           Object: offset[291] (Matlab Struct)
#             Data: time = 5495.9652609
#             Data: value = -6.499999926745659e-006
#           Object: offset[292] (Matlab Struct)
#             Data: time = 5500.96526645
#             Data: value = -3.950000063923653e-006
#           Object: offset[293] (Matlab Struct)
#             Data: time = 5505.96625075
#             Data: value = -4.049999915878288e-006
#           Object: offset[294] (Matlab Struct)
#             Data: time = 5510.9662608
#             Data: value = -6.899999789311551e-006
#           Object: offset[295] (Matlab Struct)
#             Data: time = 5515.966257
#             Data: value = -6.199999916134402e-006
#           Object: offset[296] (Matlab Struct)
#             Data: time = 5520.9662947
#             Data: value = -8.299999990413198e-006
#           Object: offset[297] (Matlab Struct)
#             Data: time = 5525.9672659
#             Data: value = -7.499999810534064e-006
#           Object: offset[298] (Matlab Struct)
#             Data: time = 5530.9682702
#             Data: value = -5.300000339047983e-006
#           Object: offset[299] (Matlab Struct)
#             Data: time = 5535.96926475
#             Data: value = -6.450000000768341e-006
#           Object: offset[300] (Matlab Struct)
#             Data: time = 5540.96928265
#             Data: value = -8.949999482865678e-006
#           Object: offset[301] (Matlab Struct)
#             Data: time = 5545.9692583
#             Data: value = -3.200000264769187e-006
#           Object: offset[302] (Matlab Struct)
#             Data: time = 5550.97024985
#             Data: value = 9.499999578110874e-007
#           Object: offset[303] (Matlab Struct)
#             Data: time = 5555.970253199999
#             Data: value = -7.999999525054591e-006
#           Object: offset[304] (Matlab Struct)
#             Data: time = 5560.97025965
#             Data: value = -7.550000191258732e-006
#           Object: offset[305] (Matlab Struct)
#             Data: time = 5565.971260400002
#             Data: value = -6.000000666972483e-006
#           Object: offset[306] (Matlab Struct)
#             Data: time = 5570.97225775
#             Data: value = -6.149999535409734e-006
#           Object: offset[307] (Matlab Struct)
#             Data: time = 5575.973258999999
#             Data: value = -6.299999768089037e-006
#           Object: offset[308] (Matlab Struct)
#             Data: time = 5580.97433705
#             Data: value = -7.449999884556746e-006
#           Object: offset[309] (Matlab Struct)
#             Data: time = 5585.97525415
# ...
#             Data: value = -3.499999365885742e-007
#           Object: offset[573] (Matlab Struct)
#             Data: time = 6906.13532445
#             Data: value = 9.499999578110874e-007
#           Object: offset[574] (Matlab Struct)
#             Data: time = 6911.136324
#             Data: value = -6.799999937356915e-006
#           Object: offset[575] (Matlab Struct)
#             Data: time = 6916.136341899999
#             Data: value = -1.389999988532509e-005
#           Object: offset[576] (Matlab Struct)
#             Data: time = 6921.1363317
#             Data: value = -1.300000349147013e-006
#           Object: offset[577] (Matlab Struct)
#             Data: time = 6926.1373371
#             Data: value = -9.200000022246968e-006
#           Object: offset[578] (Matlab Struct)
#             Data: time = 6931.137339999999
#             Data: value = -9.500000032858225e-006
#           Object: offset[579] (Matlab Struct)
#             Data: time = 6936.138336100001
#             Data: value = -1.320000001214794e-005
#           Object: offset[580] (Matlab Struct)
#             Data: time = 6941.138329699999
#             Data: value = -3.000000106112566e-007
#           Object: offset[581] (Matlab Struct)
#             Data: time = 6946.13935335
#             Data: value = -1.500002326793037e-007
#           Object: offset[582] (Matlab Struct)
#             Data: time = 6951.1393396
#             Data: value = -1.250000013897079e-005
#           Object: offset[583] (Matlab Struct)
#             Data: time = 6956.14033045
#             Data: value = -8.450000223092502e-006
#           Object: offset[584] (Matlab Struct)
#             Data: time = 6961.140325750001
#             Data: value = -3.249999735999154e-006
#           Object: offset[585] (Matlab Struct)
#             Data: time = 6966.14031935
#             Data: value = 3.750000360014383e-006
#           Object: offset[586] (Matlab Struct)
#             Data: time = 6971.142360600001
#             Data: value = -6.300000222836388e-006
#           Object: offset[587] (Matlab Struct)
#             Data: time = 6976.14432865
#             Data: value = -1.54999952428625e-006
#           Object: offset[588] (Matlab Struct)
#             Data: time = 6981.1453349
#             Data: value = -9.800000043469481e-006
#           Object: offset[589] (Matlab Struct)
#             Data: time = 6986.146325199999
#             Data: value = -2.89999979941058e-006
#           Object: offset[590] (Matlab Struct)
#             Data: time = 6991.146329400001
#             Data: value = -7.700000423938036e-006
#           Object: offset[591] (Matlab Struct)
#             Data: time = 6996.146331649999
#             Data: value = -3.149999884044519e-006
#           Object: offset[592] (Matlab Struct)
#             Data: time = 7001.14733765
#             Data: value = -1.404999966325704e-005
#           Object: offset[593] (Matlab Struct)
#             Data: time = 7006.148323400001
#             Data: value = -2.299999778188067e-006
#           Object: offset[594] (Matlab Struct)
#             Data: time = 7011.1483254
#             Data: value = -7.199999799922807e-006
#           Object: offset[595] (Matlab Struct)
#             Data: time = 7016.148327950001
#             Data: value = -7.250000180647476e-006
#           Object: offset[596] (Matlab Struct)
#             Data: time = 7021.14832495
#             Data: value = 4.550000085146166e-006
#           Object: offset[597] (Matlab Struct)
#             Data: time = 7026.148331650001
#             Data: value = -3.750000360014383e-006
#           Object: offset[598] (Matlab Struct)
#             Data: time = 7031.149329649999
#             Data: value = -9.249999948224286e-006
#           Object: offset[599] (Matlab Struct)
#             Data: time = 7036.149330250001
#             Data: value = -1.085000076272991e-005
#           Object: offset[600] (Matlab Struct)
#             Data: time = 7041.14935635
#             Data: value = -1.024999983201269e-005
#           Object: offset[601] (Matlab Struct)
#             Data: time = 7046.149348049999
#             Data: value = -1.544999986435869e-005
#           Object: offset[602] (Matlab Struct)
#             Data: time = 7051.1503881
#             Data: value = -7.900000127847306e-006
#           Object: offset[603] (Matlab Struct)
#             Data: time = 7056.15133245
#             Data: value = -9.049999789567664e-006
#           Object: offset[604] (Matlab Struct)
#             Data: time = 7061.151344049999
#             Data: value = 7.500002539018169e-007
#           Object: offset[605] (Matlab Struct)
#             Data: time = 7066.152334099999
#             Data: value = -5.80000005356851e-006
#           Object: offset[606] (Matlab Struct)
#             Data: time = 7071.15232925
#             Data: value = -4.049999915878288e-006
#           Object: offset[607] (Matlab Struct)
#             Data: time = 7076.1533329
#             Data: value = -9.200000022246968e-006
#           Object: offset[608] (Matlab Struct)
#             Data: time = 7081.153323099999
#             Data: value = -1.299999439652311e-006
#           Object: offset[609] (Matlab Struct)
#             Data: time = 7086.15334005
#             Data: value = -4.649999937100802e-006
#           Object: offset[610] (Matlab Struct)
#             Data: time = 7091.154329800001
#             Data: value = -5.400000191002619e-006
#           Object: offset[611] (Matlab Struct)
#             Data: time = 7096.1543468
#             Data: value = -1.160000010713702e-005
#           Object: offset[612] (Matlab Struct)
#             Data: time = 7101.1553325
#             Data: value = -1.050000037139398e-005
#           Object: offset[613] (Matlab Struct)
#             Data: time = 7106.15532575
#             Data: value = -9.499999578110874e-007
#           Object: offset[614] (Matlab Struct)
#             Data: time = 7111.156329
#             Data: value = -8.099999831756577e-006
#           Object: offset[615] (Matlab Struct)
#             Data: time = 7116.1563274
#             Data: value = -4.300000000512227e-006
#           Object: offset[616] (Matlab Struct)
#             Data: time = 7121.157339949999
#             Data: value = -7.049999567243503e-006
#           Object: offset[617] (Matlab Struct)
#             Data: time = 7126.1583395
#             Data: value = -1.80000006366754e-006
#           Object: offset[618] (Matlab Struct)
#             Data: time = 7131.1593267
#             Data: value = -1.80000006366754e-006
#           Object: offset[619] (Matlab Struct)
#             Data: time = 7136.1593892
#             Data: value = -4.699999863078119e-006
#           Object: offset[620] (Matlab Struct)
#             Data: time = 7141.159327949999
#             Data: value = 3.749999905267032e-006
#           Object: offset[621] (Matlab Struct)
#             Data: time = 7146.16031985
#             Data: value = -7.499993444071151e-007
#           Object: offset[622] (Matlab Struct)
#             Data: time = 7151.16034235
#             Data: value = -6.050000138202449e-006
#           Object: offset[623] (Matlab Struct)
#             Data: time = 7156.1603895
#             Data: value = -8.099999831756577e-006
#           Object: offset[624] (Matlab Struct)
#             Data: time = 7161.1613475
#             Data: value = -6.400000529538374e-006
#           Object: offset[625] (Matlab Struct)
#             Data: time = 7166.16134355
#             Data: value = -3.250000190746505e-006
#           Object: offset[626] (Matlab Struct)
#             Data: time = 7171.16333345
#             Data: value = -9.750000117492164e-006
#           Object: offset[627] (Matlab Struct)
#             Data: time = 7176.16333425
#             Data: value = -1.185000019177096e-005
#           Object: offset[628] (Matlab Struct)
#             Data: time = 7181.164335200001
#             Data: value = -7.300000561372144e-006
#           Object: offset[629] (Matlab Struct)
#             Data: time = 7186.165342299999
#             Data: value = -1.09999973574304e-006
#           Object: offset[630] (Matlab Struct)
#             Data: time = 7191.16633545
#             Data: value = -9.15000009626965e-006
#           Object: offset[631] (Matlab Struct)
#             Data: time = 7196.1663256
#             Data: value = -3.79999983124435e-006
#           Object: offset[632] (Matlab Struct)
#             Data: time = 7201.16642135
#             Data: value = -4.849999641010072e-006
#           Object: offset[633] (Matlab Struct)
#             Data: time = 7206.16732775
#             Data: value = -4.349999926489545e-006
#           Object: offset[634] (Matlab Struct)
#             Data: time = 7211.168323649999
#             Data: value = 7.450000339304097e-006
#           Object: offset[635] (Matlab Struct)
#             Data: time = 7216.168336299999
#             Data: value = 3.999998625658918e-007
#           Object: offset[636] (Matlab Struct)
#             Data: time = 7221.169509400001
#             Data: value = -4.500000159168849e-006
#           Object: offset[637] (Matlab Struct)
#             Data: time = 7226.16934565
#             Data: value = -8.349999916390516e-006
#           Object: offset[638] (Matlab Struct)
#             Data: time = 7231.1705224
#             Data: value = -5.200000032345997e-006
#           Object: offset[639] (Matlab Struct)
#             Data: time = 7236.17133435
#             Data: value = -6.149999990157085e-006
#           Object: offset[640] (Matlab Struct)
#             Data: time = 7241.172332
#             Data: value = -8.400000297115184e-006
#           Object: offset[641] (Matlab Struct)
#             Data: time = 7246.17232985
#             Data: value = -3.149999884044519e-006
#           Object: offset[642] (Matlab Struct)
#             Data: time = 7251.1723196
#             Data: value = 7.000003279244993e-007
#           Object: offset[643] (Matlab Struct)
#             Data: time = 7256.172341699999
#             Data: value = -7.500000265281415e-006
#           Object: offset[644] (Matlab Struct)
#             Data: time = 7261.1733356
#             Data: value = -3.500000275380444e-006
#           Object: offset[645] (Matlab Struct)
#             Data: time = 7266.17432955
#             Data: value = -7.650000043213368e-006
#           Object: offset[646] (Matlab Struct)
#             Data: time = 7271.17435205
#             Data: value = -5.049999799666693e-006
#           Object: offset[647] (Matlab Struct)
#             Data: time = 7276.174339499999
#             Data: value = -1.689999999143765e-005
#           Object: offset[648] (Matlab Struct)
#             Data: time = 7281.175331
#             Data: value = -5.699999746866524e-006
#           Object: offset[649] (Matlab Struct)
#             Data: time = 7286.17532715
#             Data: value = -7.14999987394549e-006
#           Object: offset[650] (Matlab Struct)
#             Data: time = 7291.175332300001
#             Data: value = -8.700000307726441e-006
#           Object: offset[651] (Matlab Struct)
#             Data: time = 7296.1763242
#             Data: value = -1.120000024457113e-005
#           Object: offset[652] (Matlab Struct)
#             Data: time = 7301.176333349999
#             Data: value = 6.500004019471817e-007
#           Object: offset[653] (Matlab Struct)
#             Data: time = 7306.1783435
#             Data: value = -6.100000064179767e-006
#           Object: offset[654] (Matlab Struct)
#             Data: time = 7311.17936
#             Data: value = -1.010000005408074e-005
#           Object: offset[655] (Matlab Struct)
#             Data: time = 7316.1803334
#             Data: value = -1.199999951495556e-005
#           Object: offset[656] (Matlab Struct)
#             Data: time = 7321.18033185
#             Data: value = -8.449999768345151e-006
#           Object: offset[657] (Matlab Struct)
#             Data: time = 7326.1813231
#             Data: value = 7.199999799922807e-006
#           Object: offset[658] (Matlab Struct)
#             Data: time = 7331.181325600001
#             Data: value = -2.900000254157931e-006
#           Object: offset[659] (Matlab Struct)
#             Data: time = 7336.182329400001
#             Data: value = -9.099999715544982e-006
#           Object: offset[660] (Matlab Struct)
#             Data: time = 7341.18233405
#             Data: value = -7.14999987394549e-006
#           Object: offset[661] (Matlab Struct)
#             Data: time = 7346.183340199999
#             Data: value = -1.37999995786231e-005
#           Object: offset[662] (Matlab Struct)
#             Data: time = 7351.183332
#             Data: value = -1.899999915622175e-006
#           Object: offset[663] (Matlab Struct)
#             Data: time = 7356.18451685
#             Data: value = -6.950000170036219e-006
#           Object: offset[664] (Matlab Struct)
#             Data: time = 7361.1853324
#             Data: value = -6.800000392104266e-006
#           Object: offset[665] (Matlab Struct)
#             Data: time = 7366.185334
#             Data: value = -6.499999926745659e-006
#           Object: offset[666] (Matlab Struct)
#             Data: time = 7371.1863575
#             Data: value = -1.06999996205559e-005
#           Object: offset[667] (Matlab Struct)
#             Data: time = 7376.18733535
#             Data: value = -1.274999976885738e-005
#           Object: offset[668] (Matlab Struct)
#             Data: time = 7381.1883387
#             Data: value = -1.569999994899263e-005
#           Object: offset[669] (Matlab Struct)
#             Data: time = 7386.190343050001
#             Data: value = -7.450000339304097e-006
#           Object: offset[670] (Matlab Struct)
#             Data: time = 7391.19033095
#             Data: value = -7.749999895168003e-006
#           Object: offset[671] (Matlab Struct)
#             Data: time = 7396.1913235
#             Data: value = 6.000000212225132e-007
#           Object: offset[672] (Matlab Struct)
#             Data: time = 7401.192334400001
#             Data: value = -7.500000265281415e-006
#           Object: offset[673] (Matlab Struct)
#             Data: time = 7406.19332555
#             Data: value = 3.499999365885742e-007
#           Object: offset[674] (Matlab Struct)
#             Data: time = 7411.19432325
#             Data: value = 3.499999365885742e-007
#           Object: offset[675] (Matlab Struct)
#             Data: time = 7416.194351650001
#             Data: value = 3.499999365885742e-007
#           Object: offset[676] (Matlab Struct)
#             Data: time = 7421.19470915
#             Data: value = 3.499999365885742e-007
#           Object: offset[677] (Matlab Struct)
#             Data: time = 7426.194810550001
#             Data: value = 3.499999365885742e-007
#           Object: offset[678] (Matlab Struct)
#             Data: time = 7431.19480965
#             Data: value = 3.499999365885742e-007
#           Object: offset[679] (Matlab Struct)
#             Data: time = 7436.19482975
#             Data: value = 3.499999365885742e-007
#           Object: offset[680] (Matlab Struct)
#             Data: time = 7441.19483685
#             Data: value = 3.499999365885742e-007
#           Object: offset[681] (Matlab Struct)
#             Data: time = 7446.19490645
#             Data: value = 3.499999365885742e-007
#           Object: offset[682] (Matlab Struct)
#             Data: time = 7451.19688385
#             Data: value = 3.499999365885742e-007
#           Object: offset[683] (Matlab Struct)
#             Data: time = 7456.19674675
#             Data: value = 3.499999365885742e-007
#           Object: offset[684] (Matlab Struct)
#             Data: time = 7461.19696295
#             Data: value = 3.499999365885742e-007
#           Object: offset[685] (Matlab Struct)
#             Data: time = 7466.19702825
#             Data: value = 3.499999365885742e-007
#           Object: offset[686] (Matlab Struct)
#             Data: time = 7471.19703845
#             Data: value = 3.499999365885742e-007
#           Object: offset[687] (Matlab Struct)
#             Data: time = 7476.19707635
#             Data: value = 3.499999365885742e-007
#           Object: offset[688] (Matlab Struct)
#             Data: time = 7481.19711515
#             Data: value = 3.499999365885742e-007
#       Data: first_timestamp = 4115.1142947
#       Data: last_timestamp = 7401.2157177
#       Data: sample_count = 1382
#     Data: time_series - Shape: (1382,)
#     Data: time_stamps - Shape: (1382,)
