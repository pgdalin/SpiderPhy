# %%
# Loading all packages available in the other scripts.

import os
import numpy as np
import pandas as pd
from scipy.io import loadmat
from scipy.signal import butter, sosfiltfilt, find_peaks

# %%
os.listdir("../../osf_files/lsl_physio_data/")
# Out:
# ['ID_044_lsl_data.mat',
#  'ID_021_lsl_data.mat',
#  'ID_024_lsl_data.mat',
#  'README.txt',
#  'ID_052_lsl_data.mat',
#  'ID_045_lsl_data.mat',
#  'ID_001_lsl_data.mat',
#  'ID_009_lsl_data.mat',
#  'ID_005_lsl_data.mat',
#  'ID_040_lsl_data.mat',
#  'ID_020_lsl_data.mat',
#  'ID_054_lsl_data.mat',
#  'ID_055_lsl_data.mat',
#  'ID_053_lsl_data.mat',
#  'ID_050_lsl_data.mat',
#  'ID_028_lsl_data.mat',
#  'ID_034_lsl_data.mat',
#  'ID_035_lsl_data.mat',
#  'ID_002_lsl_data.mat',
#  'ID_041_lsl_data.mat',
#  'ID_004_lsl_data.mat',
#  'ID_038_lsl_data.mat',
#  'ID_029_lsl_data.mat',
#  'ID_015_lsl_data.mat',
#  'ID_032_lsl_data.mat',
#  'ID_043_lsl_data.mat',
#  'ID_049_lsl_data.mat',
#  'ID_025_lsl_data.mat',
#  'ID_010_lsl_data.mat',
#  'ID_027_lsl_data.mat',
#  'ID_012_lsl_data.mat',
#  'ID_013_lsl_data.mat',
#  'ID_022_lsl_data.mat',
#  'ID_007_lsl_data.mat',
#  'ID_014_lsl_data.mat',
#  'ID_037_lsl_data.mat',
#  'ID_030_lsl_data.mat',
#  'ID_016_lsl_data.mat',
#  'ID_051_lsl_data.mat',
#  'ID_036_lsl_data.mat',
#  'ID_008_lsl_data.mat',
#  'ID_006_lsl_data.mat',
#  'ID_019_lsl_data.mat',
#  'ID_018_lsl_data.mat',
#  'ID_048_lsl_data.mat',
#  'ID_026_lsl_data.mat',
#  'ID_042_lsl_data.mat',
#  'ID_047_lsl_data.mat',
#  'ID_046_lsl_data.mat',
#  'ID_033_lsl_data.mat',
#  'ID_039_lsl_data.mat',
#  'ID_011_lsl_data.mat',
#  'ID_031_lsl_data.mat',
#  'ID_023_lsl_data.mat']

# %%
# Loading the file

BASE_DIR = os.path.abspath("../../")
FILE_PATH = os.path.join(BASE_DIR, "osf_files/lsl_physio_data/")
FILE_NAME = "ID_001_lsl_data.mat"
FULL_PATH = os.path.join(FILE_PATH, FILE_NAME)

raw_data = loadmat(FULL_PATH, squeeze_me = True, struct_as_record = False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 10
#       6 FULL_PATH = os.path.join(FILE_PATH, FILE_NAME)
#       8 raw_data = loadmat(FULL_PATH, squeeze_me = True, struct_as_record = False)
# ---> 10 streams = [c.label for c in raw_data['lsl_data']]
#      12 print(streams)
#
# AttributeError: 'mat_struct' object has no attribute 'label'
